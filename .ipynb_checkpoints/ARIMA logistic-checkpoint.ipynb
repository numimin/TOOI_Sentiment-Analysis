# %%
from statsmodels.tsa.arima.model import ARIMA

# %%
import pandas as pd
df = pd.read_csv('./signed_stem.csv')
df
# Out:
#         Unnamed: 0  Unnamed: 0.1        Date
# 0                0           168  2023-04-12  \
# 1                1           128  2023-04-12
# 2                2           174  2023-04-12
# 3                3           172  2023-04-12
# 4                4           170  2023-04-12
# ...            ...           ...         ...
# 144344      144344         81842  2015-01-01
# 144345      144345         81843  2015-01-01
# 144346      144346         81846  2015-01-01
# 144347      144347         81845  2015-01-01
# 144348      144348         81844  2015-01-01
#
#                                                      Text      Site
# 0       «ментовск войны» обошл приквел «игр престолов»...       rbc  \
# 1       рпц назва «странной» возможн пасхальн перемир ...       rbc
# 2       «велик отказ» компан росс теря деньг массов фе...       rbc
# 3       набиуллин увидел повод влиян курс рубл цб выст...       rbc
# 4       британ ввел санкц прот usm усманов член сем ке...       rbc
# ...                                                   ...       ...
# 144344  cудмедэксперт приступ осмотр тел жертв крушен ...  interfax
# 144345  кадыр сообщ уничтожен главар бандгрупп мус зав...  interfax
# 144346  роспотребнадзор призва россия перееда напива п...  interfax
# 144347  российск спасател присоедин поиск малайзийск с...  interfax
# 144348  ряд регион центральн росс отмен электричк объе...  interfax
#
#                                                       URL  HasWords  Change
# 0       https://www.rbc.ru/technology_and_media/12/04/...      True     0.0  \
# 1       https://www.rbc.ru/politics/12/04/2023/64368d1...     False     0.0
# 2       https://pro.rbc.ru/news/642fddfc9a794725b5dc71...     False     0.0
# 3       https://www.rbc.ru/economics/12/04/2023/64365f...      True     0.0
# 4       https://www.rbc.ru/politics/12/04/2023/6436633...      True     0.0
# ...                                                   ...       ...     ...
# 144344                                                NaN     False     0.0
# 144345                                                NaN     False     0.0
# 144346                                                NaN     False     0.0
# 144347                                                NaN     False     0.0
# 144348                                                NaN     False     0.0
#
#         ChangeSign
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 144344           0
# 144345           0
# 144346           0
# 144347           0
# 144348           0
#
# [144349 rows x 9 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'])
df
# Out:
#         Unnamed: 0  Unnamed: 0.1       Date
# 0                0           168 2023-04-12  \
# 1                1           128 2023-04-12
# 2                2           174 2023-04-12
# 3                3           172 2023-04-12
# 4                4           170 2023-04-12
# ...            ...           ...        ...
# 144344      144344         81842 2015-01-01
# 144345      144345         81843 2015-01-01
# 144346      144346         81846 2015-01-01
# 144347      144347         81845 2015-01-01
# 144348      144348         81844 2015-01-01
#
#                                                      Text      Site
# 0       «ментовск войны» обошл приквел «игр престолов»...       rbc  \
# 1       рпц назва «странной» возможн пасхальн перемир ...       rbc
# 2       «велик отказ» компан росс теря деньг массов фе...       rbc
# 3       набиуллин увидел повод влиян курс рубл цб выст...       rbc
# 4       британ ввел санкц прот usm усманов член сем ке...       rbc
# ...                                                   ...       ...
# 144344  cудмедэксперт приступ осмотр тел жертв крушен ...  interfax
# 144345  кадыр сообщ уничтожен главар бандгрупп мус зав...  interfax
# 144346  роспотребнадзор призва россия перееда напива п...  interfax
# 144347  российск спасател присоедин поиск малайзийск с...  interfax
# 144348  ряд регион центральн росс отмен электричк объе...  interfax
#
#                                                       URL  HasWords  Change
# 0       https://www.rbc.ru/technology_and_media/12/04/...      True     0.0  \
# 1       https://www.rbc.ru/politics/12/04/2023/64368d1...     False     0.0
# 2       https://pro.rbc.ru/news/642fddfc9a794725b5dc71...     False     0.0
# 3       https://www.rbc.ru/economics/12/04/2023/64365f...      True     0.0
# 4       https://www.rbc.ru/politics/12/04/2023/6436633...      True     0.0
# ...                                                   ...       ...     ...
# 144344                                                NaN     False     0.0
# 144345                                                NaN     False     0.0
# 144346                                                NaN     False     0.0
# 144347                                                NaN     False     0.0
# 144348                                                NaN     False     0.0
#
#         ChangeSign
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 144344           0
# 144345           0
# 144346           0
# 144347           0
# 144348           0
#
# [144349 rows x 9 columns]

# %%
import re

class Porter:
    PERFECTIVEGROUND =  re.compile(u"((ив|ивши|ившись|ыв|ывши|ывшись)|((?<=[ая])(в|вши|вшись)))$")
    REFLEXIVE = re.compile(u"(с[яь])$")
    ADJECTIVE = re.compile(u"(ее|ие|ые|ое|ими|ыми|ей|ий|ый|ой|ем|им|ым|ом|его|ого|ему|ому|их|ых|ую|юю|ая|яя|ою|ею)$")
    PARTICIPLE = re.compile(u"((ивш|ывш|ующ)|((?<=[ая])(ем|нн|вш|ющ|щ)))$")
    VERB = re.compile(u"((ила|ыла|ена|ейте|уйте|ите|или|ыли|ей|уй|ил|ыл|им|ым|ен|ило|ыло|ено|ят|ует|уют|ит|ыт|ены|ить|ыть|ишь|ую|ю)|((?<=[ая])(ла|на|ете|йте|ли|й|л|ем|н|ло|но|ет|ют|ны|ть|ешь|нно)))$")
    NOUN = re.compile(u"(а|ев|ов|ие|ье|е|иями|ями|ами|еи|ии|и|ией|ей|ой|ий|й|иям|ям|ием|ем|ам|ом|о|у|ах|иях|ях|ы|ь|ию|ью|ю|ия|ья|я)$")
    RVRE = re.compile(u"^(.*?[аеиоуыэюя])(.*)$")
    DERIVATIONAL = re.compile(u".*[^аеиоуыэюя]+[аеиоуыэюя].*ость?$")
    DER = re.compile(u"ость?$")
    SUPERLATIVE = re.compile(u"(ейше|ейш)$")
    I = re.compile(u"и$")
    P = re.compile(u"ь$")
    NN = re.compile(u"нн$")

    def stem(word):
        word = word.lower()
        word = word.replace(u'ё', u'е')
        m = re.match(Porter.RVRE, word)
        if m is None:
            return word
        if m.groups():
            pre = m.group(1)
            rv = m.group(2)
            temp = Porter.PERFECTIVEGROUND.sub('', rv, 1)
            if temp == rv:
                rv = Porter.REFLEXIVE.sub('', rv, 1)
                temp = Porter.ADJECTIVE.sub('', rv, 1)
                if temp != rv:
                    rv = temp
                    rv = Porter.PARTICIPLE.sub('', rv, 1)
                else:
                    temp = Porter.VERB.sub('', rv, 1)
                    if temp == rv:
                        rv = Porter.NOUN.sub('', rv, 1)
                    else:
                        rv = temp
            else:
                rv = temp
            
            rv = Porter.I.sub('', rv, 1)

            if re.match(Porter.DERIVATIONAL, rv):
                rv = Porter.DER.sub('', rv, 1)

            temp = Porter.P.sub('', rv, 1)
            if temp == rv:
                rv = Porter.SUPERLATIVE.sub('', rv, 1)
                rv = Porter.NN.sub(u'н', rv, 1)
            else:
                rv = temp
            word = pre+rv
        return word
    stem=staticmethod(stem)
def stemming(s):
    s = s.split()
    s = map(lambda ss: Porter.stem(ss), s)
    return " ".join(s)

# %%
with open("./words.txt", 'r', encoding='UTF-8') as file:
    lines = [line.rstrip() for line in file]
lines.append('газпром')
lines = list(set([stemming(line) for line in lines]))
indices = []
for i in range(len(lines)):
    line = lines[i]
    for c in line:
        if c in "$#-0123456789":
            indices.append(i)
            break
        if c in "abcdefghijklmnopqrstuvxyz":
            indices.append(i)
            break
lines = [lines[i] for i in range(len(lines)) if not lines[i] in indices]
dictionary = {}
for i in range(len(lines)):
    dictionary[lines[i]] = i

# %%
print(len(dictionary))
# Out:
# 76917

# %%
import numpy as np
import math

idf = np.zeros(len(dictionary))
for i in range(df.shape[0]):
    words = list(set(df['Text'].iloc[i].split()))
    for w in words:
        if w in dictionary:
            idf[dictionary[w]] += 1
idf = np.log(df.shape[0] / idf)
for i in range(len(dictionary)):
    if math.isinf(idf[i]):
        idf[i] = 0

def vectorize(text, dictionary):
    words = text.split()
    tf = np.zeros(len(dictionary))
    for w in words:
        if w in dictionary:
            tf[dictionary[w]] += 1
    tf /= len(words)
    return tf * idf
# Out:
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_242348\1720982303.py:10: RuntimeWarning: divide by zero encountered in divide
#   idf = np.log(df.shape[0] / idf)

# %%
import datetime
df = df[df['Date'] >= datetime.datetime(2023, 1, 1)]
df
# Out:
#       Unnamed: 0  Unnamed: 0.1       Date
# 0              0           168 2023-04-12  \
# 1              1           128 2023-04-12
# 2              2           174 2023-04-12
# 3              3           172 2023-04-12
# 4              4           170 2023-04-12
# ...          ...           ...        ...
# 7108        7108          9538 2023-01-01
# 7109        7109          9541 2023-01-01
# 7110        7110          9543 2023-01-01
# 7111        7111          9547 2023-01-01
# 7112        7112          9553 2023-01-01
#
#                                                    Text Site
# 0     «ментовск войны» обошл приквел «игр престолов»...  rbc  \
# 1     рпц назва «странной» возможн пасхальн перемир ...  rbc
# 2     «велик отказ» компан росс теря деньг массов фе...  rbc
# 3     набиуллин увидел повод влиян курс рубл цб выст...  rbc
# 4     британ ввел санкц прот usm усманов член сем ке...  rbc
# ...                                                 ...  ...
# 7108  гибдд раскр размер выплат сообщен пьян водител...  rbc
# 7109  сам титулова футболист мир обвин домогательств...  rbc
# 7110  роскомнадзор провер сообщен утечк дан клиент «...  rbc
# 7111  патриарх увидел взаимн недовер стран угроз кру...  rbc
# 7112  миноборон сообщ сбит беспилотник крым белгород...  rbc
#
#                                                     URL  HasWords  Change
# 0     https://www.rbc.ru/technology_and_media/12/04/...      True    0.00  \
# 1     https://www.rbc.ru/politics/12/04/2023/64368d1...     False    0.00
# 2     https://pro.rbc.ru/news/642fddfc9a794725b5dc71...     False    0.00
# 3     https://www.rbc.ru/economics/12/04/2023/64365f...      True    0.00
# 4     https://www.rbc.ru/politics/12/04/2023/6436633...      True    0.00
# ...                                                 ...       ...     ...
# 7108  https://www.autonews.ru/news/61f3dd879a7947795...     False    0.89
# 7109  https://sportrbc.ru/news/63b1856f9a79479cd0fdf...     False    0.89
# 7110  https://www.rbc.ru/society/01/01/2023/63b18d73...     False    0.89
# 7111  https://www.rbc.ru/politics/01/01/2023/63b16d8...      True    0.89
# 7112  https://www.rbc.ru/politics/01/01/2023/63b175c...     False    0.89
#
#       ChangeSign
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 7108           0
# 7109           0
# 7110           0
# 7111           1
# 7112           0
#
# [7113 rows x 9 columns]

# %%
import scipy
vectors = scipy.sparse.csr_matrix((df.shape[0], len(dictionary)), dtype = np.float32).toarray()
# Out:
# Requirement already satisfied: scipy in c:\users\egor kolyuzhnov\appdata\roaming\python\python310\site-packages (1.10.1)
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in c:\users\egor kolyuzhnov\appdata\roaming\python\python310\site-packages (from scipy) (1.24.3)

# %%
for i in range(df.shape[0]):
    vector = vectorize(df['Text'].iloc[i], dictionary)
    for j in range(len(dictionary)):
        vectors[i, j] = vector[j]
_sum = 0
for i in range(df.shape[0]):
    for j in range(len(dictionary)):
        _sum += vectors[i, j]
mean = _sum / df.shape[0] / len(dictionary)
_max = 0
for i in range(df.shape[0]):
    for j in range(len(dictionary)):
        vectors[i, j] -= mean
        _max = max(_max, abs(vectors[i, j]))
for i in range(df.shape[0]):
    for j in range(len(dictionary)):
        vectors[i, j] /= _max

# %%
import pickle
import sklearn
X = vectors
lr = pickle.load(open('./logistic.model', 'rb'))
y = lr.predict(X)
# Out:
# 0.6661043160410516

# %%
date_counts = {}
date_score = {}
for i in range(df.shape[0]):
    date = df['Date'].iloc[i]
    if date in date_counts:
        date_counts[date] += 1
    else:
        date_counts[date] = 0
    if date in date_score:
        date_score[date] += y[i]
    else:
        date_score[date] = 0
for date in sorted(date_counts.keys()):
    date_score[date] /= date_counts[date]

# %%
import pandas as pd
import datetime

funds = pd.read_excel("./gazprom-moscow-exchange.xlsx")
funds['Дата'] = pd.to_datetime(funds['Дата'], dayfirst=True)
funds = funds.sort_values("Дата")
funds = funds[funds['Дата'] >= datetime.datetime(2023, 1, 1)]
funds.head(10)
prices = {}
for i in range(funds.shape[0] - 1):
    date = funds['Дата'].iloc[i]
    end = funds['Дата'].iloc[i + 1]
    while date < end:
        prices[date] = funds['Цена avg'].iloc[i]
        date += datetime.timedelta(days=1)
dates = []
scores = []
prices_list = []
for date in sorted(prices.keys()):
    if date in date_score.keys():
        dates.append(date)
        scores.append(date_score[date])        
        prices_list.append(prices[date])

# %%
exog = scores
endog = prices_list
# Out:
# [0.3448275862068966, 0.3333333333333333, -0.40625, -0.5, 0.14285714285714285, 0.2777777777777778, 0.18421052631578946, 0.23529411764705882, -0.16, 0.3142857142857143, 0.20408163265306123, -0.28125, 0.3176470588235294, 0.27419354838709675, 0.14285714285714285, -0.3269230769230769, -0.41904761904761906, -0.3968253968253968, -0.3448275862068966, 0.2971014492753623, 0.3055555555555556, 0.15384615384615385, -0.29365079365079366, -0.2621359223300971, 0.2857142857142857, 0.3269230769230769, 0.42857142857142855, 0.14285714285714285, 0.08695652173913043, 0.4, -0.45454545454545453, -0.38235294117647056, 0.2608695652173913, -0.4424778761061947, -0.3387096774193548, -0.17647058823529413, 0.33980582524271846, -0.3, 0.40404040404040403, -0.4117647058823529, -0.36054421768707484, -0.22077922077922077, -0.23255813953488372, -0.3508771929824561, -0.2833333333333333, -0.4117647058823529, 0.24324324324324326, -0.3142857142857143, -0.2608695652173913, 0.0, 0.37209302325581395, -0.34782608695652173, 0.3023255813953488, 0.16666666666666666, 0.37362637362637363, 0.5, 0.2736842105263158, 0.35714285714285715, 0.2857142857142857, -0.3870967741935484, 0.3391304347826087, 0.36792452830188677, 0.38961038961038963, 0.26136363636363635, -0.4772727272727273, -0.45454545454545453, -0.08333333333333333, -0.59375, -0.28, -0.4, 0.0, 0.4, -0.40540540540540543, -0.4358974358974359, 0.35106382978723405, 0.36585365853658536, 0.3333333333333333, 0.3010752688172043, 0.3275862068965517, -0.44166666666666665, -0.31092436974789917, -0.344, 0.358974358974359, 0.2966101694915254, 0.225, -0.46875, 0.3225806451612903, 0.0, -0.23404255319148937, 0.3235294117647059, 0.21212121212121213, 0.09090909090909091, 0.2463768115942029, -0.3643410852713178, 0.34615384615384615, -0.3826086956521739, 0.4830508474576271, 0.35051546391752575, 0.29213483146067415]

# %%
count = int(len(scores) * 0.8)

# %%
scores = []
with open("exog.txt") as inf:
    for line in inf.readlines():
        scores.append(float(line[:-1]))
prices = []
with open("endog.txt") as inf:
    for line in inf.readlines():
        prices.append(float(line[:-1]))
dates = []
with open("dates.txt") as inf:
    for line in inf.readlines():
        dates.append(datetime.datetime.strptime(line, "%Y-%m-%d %H:%M:%S "))

# %%
exog = scores
endog = np.array(prices)
count = int(len(scores) * 0.8)
from statsmodels.tsa.statespace.sarimax import SARIMAX
d = 1
doh = 100 * (endog[1:] - endog[:-1]) / endog[:-1]
arimax = SARIMAX(doh[1:count], exog[:count-1], order=(1, d, 0))
res = arimax.fit()
old_pred = res.predict()
pred = res.predict()[d:-1]
plt.plot(dates[:count-2-d], pred)
plt.plot(dates[:count-2-d], doh[:count-2-d])
print(r2_score(prices[:count-2-d], pred))
import math
err_var = np.sqrt(((doh[:count-2-d] - pred) ** 2).sum())
act_var = np.sqrt((doh[:count-2-d] ** 2).sum())
r2 = 1 - err_var / act_var
print(r2)
print(np.abs((doh[:count-2-d] - pred)).mean())
# Out:
# -2595.9393991212523
# 0.4488329796889544
# 3471245.2689082287

# %%
plot = zip(doh[:-1], doh[1:])
plot = sorted(plot, key=lambda x: x[0])
x = [p[0] for p in plot]
y = [p[1] for p in plot]
plt.plot(x, y)

# %%
res = res.apply(endog[:])
pred = res.predict()[d:]
for i in range(len(pred)):
    pred[i] = math.exp(pred[i])
for i in range(len(prices)):
    prices[i] = math.exp(prices[i])
plt.plot(dates[d:], pred)
plt.plot(dates[d:], prices[d:])
print(r2_score(prices[d:], pred))
price_predictions = pd.DataFrame(np.array([pred, prices[d:]]).reshape(-1, 2), columns=['predicted', 'actual'])
# Out:
# 0.9198227136620905

# %%
with open("./predicted.txt", 'w') as fout:
    for predicted in pred:
        fout.write(str(predicted) + '\n')

# %%
def sign(x):
    if x < 0:
        return -1
    elif x > 0:
        return 1
    else:
        return 0

# %%
print(sum(sign(scores[i + 1]) == sign(pred[i] ) for i in range(len(pred))) ) 
print(len(pred))
# Out:
# 446
# 828

# %%
price_predictions['error'] = (price_predictions['actual'] - price_predictions['predicted']).abs() / price_predictions['actual']

# %%
price_predictions
# Out:
#     predicted    actual         error
# 0    5.092026  5.092026  3.488507e-16
# 1    5.097480  5.091349  1.204168e-03
# 2    5.084252  5.087282  5.956435e-04
# 3    5.087282  5.087282  0.000000e+00
# 4    5.091657  5.087653  7.870160e-04
# ..        ...       ...           ...
# 93   5.135210  5.135210  0.000000e+00
# 94   5.135210  5.137209  3.891563e-04
# 95   5.157963  5.153003  9.625870e-04
# 96   5.155255  5.149237  1.168686e-03
# 97   5.149237  5.149237  0.000000e+00
#
# [98 rows x 3 columns]

# %%
price_predictions['error'].iloc[count:].mean()
# Out:
# 0.001276591393647611

# %%
import math
err_var = 0
act_var = 0
for i in range(count, price_predictions.shape[0]):
    error = price_predictions['error'].iloc[i]
    actual = price_predictions['actual'].iloc[i]
    err_var += error ** 2    
    act_var += actual ** 2
err_var = math.sqrt(err_var)
act_var = math.sqrt(act_var)
r2 = 1 - err_var / act_var
print(r2)
# Out:
# 0.9997022110739536
