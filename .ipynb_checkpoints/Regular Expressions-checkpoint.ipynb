# %%
import re

# %%
text = ""
with open("./T1.txt", 'r', encoding='UTF-8') as file:
    for line in file:
        text += line
abbrev = re.compile("[А-Я]{2,}")
match = re.findall(abbrev, text)
match
# Out:
# ['ПЕРЕВОД',
#  'ИДИОМАТИЧЕСКИХ',
#  'ВЫРАЖЕНИЙ',
#  'СИСТЕМАХ',
#  'МАШИННОГО',
#  'ПЕРЕВОДА',
#  'ИЯ',
#  'ПЯ',
#  'ПЯ',
#  'ИЯ',
#  'ПЯ',
#  'ИЯ',
#  'ПЯ']

# %%
abbrev = re.compile("\\[[^\]]*\\]")
match = re.findall(abbrev, text)
match
# Out:
# ['[Зубов, 2007, с. 253]',
#  '[там же, с. 254]',
#  '[Мамедова, 2006, с. 61]',
#  '[Борисевич, 1972, с. 14]',
#  '[Марчук, 1983, с. 42]',
#  '[Мамедова, 2006, с. 122]',
#  '[Борисевич, 1973, с. 266]',
#  '[там же, с. 275]',
#  '[там же, с. 275]',
#  '[Ровенский, 1960, с. 52]',
#  '[Баранов, 2003, с. 171]',
#  '[Языкознание.ру, эл. рес.]',
#  '[Мамедова, 2006, с. 77]',
#  '[Дзенс, 2007, с. 169]']

# %%
abbrev = re.compile('«[^»]*\»')
match = re.findall(abbrev, text)
match
# Out:
# ['«выполняемое компьютером действие по преобразованию текста на одном естественном языке в текст на другом естественном языке при сохранении эквивалентности содержания, а также результат такого действия»',
#  '«представление»',
#  '«…Можно усматривать три степени различия между выражениями (словами, словосочетаниями и целыми предложениями): различие затрагивает либо только представление, либо смысл, но не денотат (референт), либо, наконец, и смысл, и денотат… Разница между оригиналом не должна, вообще говоря, выходить за пределы первой степени различия»',
#  '«Разрешение идиоматичности является одной из формальных операций, обеспечивающих анализ и синтез в системах машинного перевода, и производится либо с помощью стандартных грамматических и лексических программ анализа текста, работающих совместно с автоматическим словарем, либо путём прямого соотнесения входного и выходного сегментов. Во втором случае и входной, и выходной сегменты рассматриваются как неделимые обороты. Один или несколько выходных оборотов или словоформ, поставленных в соответствие каждому входному обороту, составляют автоматический словарь оборотов»',
#  '«лингвистическое исследование их дистрибуции»',
#  '«Оборот считается цельным, если он имеет неизменный состав и между его элементами нельзя вставить другие единицы»',
#  '«универсального семантического языка»',
#  '«Теория и практика перевода»',
#  '«Множество окончаний хранится в виде древесных структур, что обеспечивает не только эффективный способ хранения, но и эффективный алгоритм морфологического анализа»',
#  '«Глубокоуважаемый Господин! \nСегодня я вынужден с Вами серьезно поговорить. Я целый день ломаю себе голову, но никак не могу понять, почему Вы считаете, что Вы можете вскружить голову моей жене; именно Вы, в Вашемто возрасте! Я понимаю, моя жена сильно влюбилась. Но Вы можете делать все, что угодно, я не потерплю ваших отношений за моей спиной»',
#  '«Глубокоуважаемый Господин! \nСегодня я должен Вам основательно промыть мозги. Я уже давно ломаю себе голову, но до меня никак не доходит, с чего вы взяли, что Вы можете пудрить мозги моей жене; именно Вы, которому плешь проела голову! Я понимаю, моя жена втрескалась по уши. Но Вы можете хоть в лепешку разбиться, я не стану терпеть, чтобы Вы крутили роман за моей спиной»',
#  '«Глубокоуважаемый господин! \nЯ должен мыть Вам сегодня однажды энергично голову. Я ломаю себе голову уже целыми днями, и это не хочет войти мне в голову, почему Вы сели, собственно, в голову скручивать голову моей женщины; как раз Вас, который уже голова по волосам растет! Я знаю, моя жена установлена с головы до ног на любовь. Но Вы можете становиться на голову, я не буду терпеть это, что Вы соединяете обоих головы»']

# %%
abbrev = re.compile('Согласно [^,]*(?=,)')
match = re.findall(abbrev, text)
match
# Out:
# ['Согласно М. Таубе',
#  'Согласно его концепции',
#  'Согласно исследованиям Борисевича А.Д.']

# %%
abbrev = re.compile('[^.\n]* — это [^.]*\.')
lm = re.findall(abbrev, text)
#abbrev = re.compile('[^.\n]*(?= — это )')
#rm = re.findall(abbrev, text)
#list(zip(rm, lm))
lm
# Out:
# ['Машинный, или автоматический, перевод — это «выполняемое компьютером действие по преобразованию текста на одном естественном языке в текст на другом естественном языке при сохранении эквивалентности содержания, а также результат такого действия» [Зубов, 2007, с',
#  ' UNL — это универсальный семантико-синтаксический язык, представленный для описания, хранения и распространения информации в сети Internet в независимом от какого-либо естественного языка виде [Языкознание']

# %%
abbrev = re.compile('(?<=[^ \n«…])[А-Я][а-я]+')
match = re.findall(abbrev, text)
match
# Out:
# ['Зубов',
#  'Мамедова',
#  'Борисевич',
#  'Фреге',
#  'Марчук',
#  'Мамедова',
#  'Борисевич',
#  'Ровенский',
#  'Баранов',
#  'Языкознание',
#  'Мамедова',
#  'Дзенс']
