# %%
import pandas as pd
df = pd.read_csv("./interfax.csv", parse_dates=True)
df['Text'] = df['Title'] + " " + df['Article'] + " " + df['Tags']
df = df.drop(columns=['Title', 'Article', 'Tags'])

# %%
df = df[df['Text'].notnull()]

# %%
df.head(10)
df.describe(include='all')
# Out:
#           Unnamed: 0                 Date  \
# count   77953.000000                77041
# unique           NaN                74810
# top              NaN  2018-10-04 07:41:00
# freq             NaN                    6
# mean    41047.695445                  NaN
# std     23765.369328                  NaN
# min         0.000000                  NaN
# 25%     20380.000000                  NaN
# 50%     41039.000000                  NaN
# 75%     61749.000000                  NaN
# max     81877.000000                  NaN
#
#                                                      Text
# count                                               77953
# unique                                              76008
# top     РЖД в ближайшие годы оборудует плацкартные ваг...
# freq                                                    6
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN

# %%
isnull = df['Date'].isnull()
for i in range(1, df.shape[0]):
    if isnull.iloc[i]:
        df['Date'].iloc[i] = df['Date'].iloc[i - 1]
df['Date'] = pd.to_datetime(df['Date'])
# Out:
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\3773003364.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'].iloc[i] = df['Date'].iloc[i - 1]

# %%
marks = ['!', '\"', "\'", '\(', '\)', '\-', '\+', ',', '\.', ';', ':', '<', '>', '\[', '\]', '%', '\$']
for m in marks:
    df['Text'] = df['Text'].replace(m, " ", regex=True)
numbers = [str(i) for i in range(10)]
for n in numbers:
    df['Text'] = df['Text'].replace(n, " ", regex=True)
df['Text'] = df['Text'].str.lower()

# %%
df = df.drop_duplicates(['Text'])

# %%
aux_words = [
    'даже',
    "еще",
    "именно",
    "как раз",
    "только",
    "просто",
    "прямо",
    "буквально",
    "хоть",
    "хотя бы",
    "почти",
    "чуть не",
    "чуть ли не",
    "едва ли",
    "все таки",
    "все же",
    "но",
    "да",
    "или",
    "то есть",
    "именно",
    "как то",
    "будь то",
    "то",
    "не",
    "ли",
    "как и",
    "чем",
    "тем",
    "словно",
    "точно",
    "в целом",
    "в общем",
    "в основном",
    "во многом",
    "во",
    "без малого",
    "в итоге",
    "в результате",
    "к слову",
    "в идеале",
    "в частности",
    "что",
    "а вдобавок",
    "а именно",
    "а также",
    "а то",
    "будто",
    "вдобавок",
    "даже",
    "же",
    "едва",
    "ежели",
    "если",
    "зато",
    "зачем",
    "или",
    "как",
    "когда",
    "коли",
    "из",
    "однако",
    "пока",
    "потому",
    "пусть",
    "также",
    "тоже",
    "хотя",
    "точно",
    "чем",
    "чтобы",
    "без",
    "близ",
    "во",
    "вместо",
    "вне",
    "для",
    "до",
    "за",
    "из",
    "из за",
    "из под",
    "кроме",
    "между",
    "на",
    "над",
    "об",
    "от",
    "перед",
    "по",
    "под",
    "при",
    "про",
    "ради",
    "со",
    "сквозь",
    "среди",
    "через",
    "здесь"
]
for w in aux_words:
    df['Text'] = df['Text'].replace(" " + w + " ", " ", regex=True)
    df['Text'] = df['Text'].replace("^" + w + " ", " ", regex=True)
    df['Text'] = df['Text'].replace(" " + w + "$", " ", regex=True)
letters = list(map(chr, range(ord('а'), ord('я')+1)))
for l in letters:
    df['Text'] = df['Text'].replace(" " + l + " ", " ", regex=True)
    df['Text'] = df['Text'].replace("^" + l + " ", " ", regex=True)
    df['Text'] = df['Text'].replace(" " + l + "$", " ", regex=True)

# %%
import re

class Porter:
    PERFECTIVEGROUND =  re.compile(u"((ив|ивши|ившись|ыв|ывши|ывшись)|((?<=[ая])(в|вши|вшись)))$")
    REFLEXIVE = re.compile(u"(с[яь])$")
    ADJECTIVE = re.compile(u"(ее|ие|ые|ое|ими|ыми|ей|ий|ый|ой|ем|им|ым|ом|его|ого|ему|ому|их|ых|ую|юю|ая|яя|ою|ею)$")
    PARTICIPLE = re.compile(u"((ивш|ывш|ующ)|((?<=[ая])(ем|нн|вш|ющ|щ)))$")
    VERB = re.compile(u"((ила|ыла|ена|ейте|уйте|ите|или|ыли|ей|уй|ил|ыл|им|ым|ен|ило|ыло|ено|ят|ует|уют|ит|ыт|ены|ить|ыть|ишь|ую|ю)|((?<=[ая])(ла|на|ете|йте|ли|й|л|ем|н|ло|но|ет|ют|ны|ть|ешь|нно)))$")
    NOUN = re.compile(u"(а|ев|ов|ие|ье|е|иями|ями|ами|еи|ии|и|ией|ей|ой|ий|й|иям|ям|ием|ем|ам|ом|о|у|ах|иях|ях|ы|ь|ию|ью|ю|ия|ья|я)$")
    RVRE = re.compile(u"^(.*?[аеиоуыэюя])(.*)$")
    DERIVATIONAL = re.compile(u".*[^аеиоуыэюя]+[аеиоуыэюя].*ость?$")
    DER = re.compile(u"ость?$")
    SUPERLATIVE = re.compile(u"(ейше|ейш)$")
    I = re.compile(u"и$")
    P = re.compile(u"ь$")
    NN = re.compile(u"нн$")

    def stem(word):
        word = word.lower()
        word = word.replace(u'ё', u'е')
        m = re.match(Porter.RVRE, word)
        if m is None:
            return word
        if m.groups():
            pre = m.group(1)
            rv = m.group(2)
            temp = Porter.PERFECTIVEGROUND.sub('', rv, 1)
            if temp == rv:
                rv = Porter.REFLEXIVE.sub('', rv, 1)
                temp = Porter.ADJECTIVE.sub('', rv, 1)
                if temp != rv:
                    rv = temp
                    rv = Porter.PARTICIPLE.sub('', rv, 1)
                else:
                    temp = Porter.VERB.sub('', rv, 1)
                    if temp == rv:
                        rv = Porter.NOUN.sub('', rv, 1)
                    else:
                        rv = temp
            else:
                rv = temp
            
            rv = Porter.I.sub('', rv, 1)

            if re.match(Porter.DERIVATIONAL, rv):
                rv = Porter.DER.sub('', rv, 1)

            temp = Porter.P.sub('', rv, 1)
            if temp == rv:
                rv = Porter.SUPERLATIVE.sub('', rv, 1)
                rv = Porter.NN.sub(u'н', rv, 1)
            else:
                rv = temp
            word = pre+rv
        return word
    stem=staticmethod(stem)

# %%
def stemming(s):
    s = s.split()
    s = map(lambda ss: Porter.stem(ss), s)
    return " ".join(s)
for i in range(df.shape[0]):
    df['Text'].iloc[i] = stemming(df['Text'].iloc[i])
df.head(10)
# Out:
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\630041118.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Text'].iloc[i] = stemming(df['Text'].iloc[i])
#    Unnamed: 0                Date  \
# 0           0 2023-04-09 12:16:00
# 1           1 2023-04-09 11:33:00
# 2           2 2023-04-09 11:21:00
# 3           3 2023-04-09 11:02:00
# 4           4 2023-04-09 11:22:00
# 5           5 2023-04-09 06:08:00
# 6           6 2023-04-09 08:33:00
# 7           7 2023-04-09 00:09:00
# 8           8 2023-04-09 04:44:00
# 9           9 2023-04-08 21:47:00
#
#                                                 Text
# 0  марсел пят человек пострада обрушен жил дом мо...
# 1  песк назва неадекватн реакц запад план рф пост...
# 2  воен рф созда спецгрупп борьб западн танк моск...
# 3  полиц ира будет отслежива ношен хиджаб помощ к...
# 4  воен рф созда спецгрупп борьб западн танк моск...
# 5  сша направ подводн лодк красн мор напряжен отн...
# 6  случ эт ноч воскресен апрел обстрел израил сир...
# 7  православн отмеча вербн воскресен москв апрел ...
# 8  три ракет был выпущ сир сторон голанск высот а...
# 9  динам спартак сыгра внич матч рпл собол заб св...

# %%
df['Text'].iloc[8]
# Out:
# 'три ракет был выпущ сир сторон голанск высот арм израил ответ нанесл удар сирийск территор москв апрел interfax ru меньш мер три ракет был выпущ сторон голанск высот территор сир ран утр воскресен сообща газет the jerusalem post ссылк пресс служб израильск арм три ракет был запущ израил сир поздн вечер суббот две упа открыт местност юг голанск высот одн был перехвач железн купол говор публикац ответствен обстрел взял себ ополчен лив ал кудс заяв он стал ответ нападен мечет ал акс армейск пресс служб проинформирова пол пуск ракет арм израил откр артиллерийск огон район сирийск территор откуд был запущ ракет врем отмеча газет суббот вечер больш групп палестинц забаррикадирова мечет ал акс иерусалим полиц вошл комплекс где располож мечет вскор посл тог наход не люд заперл министерств иностра дел иордан предупред суббот вечер катастрофическ последств случа применен полиц сил выдворен палестинц подчеркнув так шаг подтолкнет ситуац больш напряжен насил котор все заплат цен мид израил ответ предупрежден иордан заяв те котор оскверня святост мечет ал акс забаррикадирова внутр не явля опасн толп радикализирова подстрека хамас друг террористическ организац представител движен хамас иерусалим мухаммад хамад предупред агресс будет встреч сопротивлен эквивалентн размер преступлен сообща ран тел авив израильтянин арабск происхожден соверш автомобил наезд пешеход попыта расстреля прохож ег нейтрализова полицейск теракт сконча летн итальянск турист сем человек граждан великобритан итал пострада тог пятниц населен пункт хамр западн берег иорда стрельб погибл две женщин одн получ ранен последн дни фон священ мусульма месяц рамада еврейск песах наблюда обострен палестин израильск конфликт ноч пятниц сектор газ израил был пущ бол ракет израильск воен нанесл удар объект палестинск движен хамас ливан премьер министр израил биньямин нетаньях посл теракт тел авив попрос полиц арм активизирова участ обеспечен безопасн гражда написа газет the times of israel дан издан нетаньях распоряд пограничн полиц стран призва всех сво резервист тог он приказа воен командован выдел дополнительн подразделен обеспечен безопасн населен сир израил голанск высот'

# %%
import datetime
words = [
    "газпром",
    "газ",
    "нефть",
    "бензин",
    "санкции",
    "кризис",
    "рубль",
    "рост",
    "падение",
    "цена",
    "подорожание",
    "удешевение"
]
_filter = df['Text'].str.contains(" " + stemming(words[0]) + " ")
for w in words:
    s = stemming(w)
    _filter |= df['Text'].str.contains(" " + s + " ")
    _filter |= df['Text'].str.contains("^" + s + " ")
    _filter |= df['Text'].str.contains(" " + s + "$")
filtered = df[_filter]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_58308\2851649406.py in <module>
#      18     s = stemming(w)
#      19     _filter |= df['Text'].str.contains(" " + s + " ")
# ---> 20     _filter |= df['Text'].str.contains("^" + s + " ")
#      21     _filter |= df['Text'].str.contains(" " + s + "$")
#      22 filtered = df[_filter]
#
# ~\anaconda3\lib\site-packages\pandas\core\strings\accessor.py in wrapper(self, *args, **kwargs)
#     123                 )
#     124                 raise TypeError(msg)
# --> 125             return func(self, *args, **kwargs)
#     126
#     127         wrapper.__name__ = func_name
#
# ~\anaconda3\lib\site-packages\pandas\core\strings\accessor.py in contains(self, pat, case, flags, na, regex)
#    1220             )
#    1221
# -> 1222         result = self._data.array._str_contains(pat, case, flags, na, regex)
#    1223         return self._wrap_result(result, fill_value=na, returns_string=False)
#    1224
#
# ~\anaconda3\lib\site-packages\pandas\core\strings\object_array.py in _str_contains(self, pat, case, flags, na, regex)
#     129                 upper_pat = pat.upper()
#     130                 f = lambda x: upper_pat in x.upper()
# --> 131         return self._str_map(f, na, dtype=np.dtype("bool"))
#     132
#     133     def _str_startswith(self, pat, na=None):
#
# ~\anaconda3\lib\site-packages\pandas\core\strings\object_array.py in _str_map(self, f, na_value, dtype, convert)
#      69         map_convert = convert and not np.all(mask)
#      70         try:
# ---> 71             result = lib.map_infer_mask(arr, f, mask.view(np.uint8), map_convert)
#      72         except (TypeError, AttributeError) as err:
#      73             # Reraise the exception if callable `f` got wrong number of args.
#
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer_mask()
#
# ~\anaconda3\lib\site-packages\pandas\core\strings\object_array.py in <lambda>(x)
#     122             pat = re.compile(pat, flags=flags)
#     123
# --> 124             f = lambda x: pat.search(x) is not None
#     125         else:
#     126             if case:
#
# KeyboardInterrupt:

# %%
before_start = filtered[filtered['Date'] >= datetime.datetime(2015, 1, 1)]
for i in range(before_start.shape[0]):
    date = before_start['Date'].iloc[i]
    before_start['Date'].iloc[i] = datetime.datetime(date.year, date.month, date.day)
before_start.describe(include="all", datetime_is_numeric=True)
before_start
# Out:
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\365184396.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   before_start['Date'].iloc[i] = datetime.datetime(date.year, date.month, date.day)
#        Unnamed: 0       Date  \
# 3               3 2023-04-09
# 8               8 2023-04-09
# 10             10 2023-04-08
# 13             13 2023-04-08
# 14             14 2023-04-08
# ...           ...        ...
# 81823       81823 2015-01-05
# 81824       81824 2015-01-05
# 81828       81828 2015-01-04
# 81832       81832 2015-01-04
# 81837       81837 2015-01-03
#
#                                                     Text
# 3      полиц ира будет отслежива ношен хиджаб помощ к...
# 8      три ракет был выпущ сир сторон голанск высот а...
# 10     произошл ден суббот апрел ракет крым учен тайв...
# 13     сотрудник tesla год пересыла друг друг виде ка...
# 14     twitch wikimedia гроз миллион штраф неудален з...
# ...                                                  ...
# 81823  президент франц заяв возможн отм санкц отношен...
# 81824  правительств продолж субсидирова региональн ав...
# 81828  итог главн пользовател осваива интернет рост р...
# 81832  правительств росс обнов перечен жизнен важн ле...
# 81837  итог сам сложн год туризм минувш год стал тури...
#
# [24235 rows x 3 columns]

# %%
funds = pd.read_excel("./gazprom-moscow-exchange.xlsx")
funds['Дата'] = pd.to_datetime(funds['Дата'])
funds['Change'] = 0
funds = funds.sort_values("Дата")
for i in range(1, funds.shape[0]):
    funds['Change'].iloc[i] = funds['Цена avg'].iloc[i] - funds['Цена avg'].iloc[i - 1]
funds.tail(10)
# Out:
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '31.03.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '30.03.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '29.03.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '28.03.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '27.03.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '24.03.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '23.03.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '22.03.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '21.03.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '20.03.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '17.03.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '16.03.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '15.03.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '14.03.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '13.03.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '28.02.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '27.02.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '24.02.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '22.02.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '21.02.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '20.02.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '17.02.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '16.02.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '15.02.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '14.02.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '13.02.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '31.01.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '30.01.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '27.01.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '26.01.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '25.01.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '24.01.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '23.01.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '20.01.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '19.01.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '18.01.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '17.01.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '16.01.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '13.01.2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '30.12.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '29.12.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '28.12.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '27.12.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '26.12.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '23.12.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '22.12.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '21.12.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '20.12.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '19.12.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '16.12.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '15.12.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '14.12.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '13.12.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '30.11.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '29.11.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '28.11.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '25.11.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '24.11.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '23.11.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '22.11.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '21.11.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '18.11.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '17.11.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '16.11.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '15.11.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '14.11.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '31.10.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '28.10.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '27.10.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '26.10.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '25.10.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '24.10.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '21.10.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '20.10.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '19.10.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '18.10.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '17.10.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '14.10.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '13.10.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '30.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '29.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '28.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '27.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '26.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '23.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '22.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '21.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '20.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '19.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '16.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '15.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '14.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '13.09.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '31.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '30.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '29.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '26.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '25.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '24.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '23.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '22.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '19.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '18.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '17.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '16.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '15.08.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '29.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '28.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '27.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '26.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '25.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '22.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '21.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '20.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '19.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '18.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '15.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '14.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '13.07.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '30.06.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '29.06.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '28.06.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '27.06.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '24.06.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '23.06.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '22.06.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '21.06.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '20.06.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '17.06.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '16.06.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '15.06.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '14.06.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '31.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '30.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '27.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '26.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '25.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '24.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '23.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '20.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '19.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '18.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '17.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '16.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '13.05.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '29.04.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '28.04.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '27.04.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '26.04.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '25.04.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '22.04.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '21.04.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '20.04.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '19.04.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '18.04.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '15.04.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '14.04.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '13.04.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '31.03.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '30.03.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '29.03.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '28.03.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '25.03.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '24.03.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '25.02.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '24.02.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '22.02.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '21.02.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '18.02.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '17.02.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '16.02.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '15.02.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '14.02.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '31.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '28.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '27.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '26.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '25.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '24.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '21.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '20.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '19.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '18.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '17.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '14.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '13.01.2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# ...
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '18.05.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '15.05.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '14.05.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '13.05.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '30.04.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '29.04.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '28.04.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '27.04.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '24.04.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '23.04.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '22.04.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '21.04.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '20.04.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '17.04.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '16.04.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '15.04.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '14.04.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '13.04.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '31.03.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '30.03.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '27.03.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '26.03.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '25.03.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '24.03.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '23.03.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '20.03.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '19.03.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '18.03.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '17.03.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '16.03.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '13.03.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '27.02.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '26.02.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '25.02.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '24.02.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '20.02.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '19.02.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '18.02.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '17.02.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '16.02.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '13.02.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '30.01.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '29.01.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '28.01.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '27.01.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '26.01.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '23.01.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '22.01.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '21.01.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '20.01.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '19.01.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '16.01.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '15.01.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '14.01.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:2: UserWarning: Parsing '13.01.2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   funds['Дата'] = pd.to_datetime(funds['Дата'])
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\807830516.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   funds['Change'].iloc[i] = funds['Цена avg'].iloc[i] - funds['Цена avg'].iloc[i - 1]
#          Дата     Bid     Ask  Цена open  Цена min  Цена max  Цена last  \
# 41 2023-08-02  158.17  158.18     160.01    157.82    160.42     158.18
# 63 2023-09-01  162.70  162.71     162.99    161.88    163.49     162.71
# 40 2023-09-02  159.16  159.19     158.50    157.60    160.44     159.19
# 22 2023-09-03  161.20  161.21     162.21    161.12    163.18     161.21
# 62 2023-10-01  162.10  162.11     162.71    161.44    162.98     162.10
# 39 2023-10-02  158.68  158.73     159.07    158.32    159.46     158.68
# 21 2023-10-03  160.02  160.04     160.50    159.51    161.29     160.04
# 0  2023-10-04  174.54  174.55     173.55    173.23    175.20     174.54
# 61 2023-11-01  165.81  165.83     162.05    161.70    167.19     165.83
# 60 2023-12-01  164.17  164.19     165.71    163.75    165.79     164.17
#
#     Цена avg      Оборот  Кол-во сделок  Change
# 41    158.86  2651241562          65896  -13.44
# 63    162.66  1585386826          40900    3.80
# 40    159.27  4405526876          78359   -3.39
# 22    161.86  2258690982          49965    2.59
# 62    162.01  1190522691          32299    0.15
# 39    158.71  1567193270          38975   -3.30
# 21    160.31  2764175212          50840    1.60
# 0     174.18  4070633698          64768   13.87
# 61    164.37  4152716828          77414   -9.81
# 60    164.76  1874103142          48382    0.39

# %%
changes = {}
for i in range(1, funds.shape[0]):
    start = funds["Дата"].iloc[i - 1]
    end = funds["Дата"].iloc[i]
    date = start
    while date < end:
        changes[str(date)] = funds['Change'].iloc[i - 1]
        date += datetime.timedelta(days=1)
print(list(map(lambda k: (k, changes[k]), reversed(sorted(changes)))))
# Out:
# [('2023-11-30 00:00:00', -9.810000000000002), ('2023-11-29 00:00:00', -9.810000000000002), ('2023-11-28 00:00:00', -9.810000000000002), ('2023-11-27 00:00:00', -9.810000000000002), ('2023-11-26 00:00:00', -9.810000000000002), ('2023-11-25 00:00:00', -9.810000000000002), ('2023-11-24 00:00:00', -9.810000000000002), ('2023-11-23 00:00:00', -9.810000000000002), ('2023-11-22 00:00:00', -9.810000000000002), ('2023-11-21 00:00:00', -9.810000000000002), ('2023-11-20 00:00:00', -9.810000000000002), ('2023-11-19 00:00:00', -9.810000000000002), ('2023-11-18 00:00:00', -9.810000000000002), ('2023-11-17 00:00:00', -9.810000000000002), ('2023-11-16 00:00:00', -9.810000000000002), ('2023-11-15 00:00:00', -9.810000000000002), ('2023-11-14 00:00:00', -9.810000000000002), ('2023-11-13 00:00:00', -9.810000000000002), ('2023-11-12 00:00:00', -9.810000000000002), ('2023-11-11 00:00:00', -9.810000000000002), ('2023-11-10 00:00:00', -9.810000000000002), ('2023-11-09 00:00:00', -9.810000000000002), ('2023-11-08 00:00:00', -9.810000000000002), ('2023-11-07 00:00:00', -9.810000000000002), ('2023-11-06 00:00:00', -9.810000000000002), ('2023-11-05 00:00:00', -9.810000000000002), ('2023-11-04 00:00:00', -9.810000000000002), ('2023-11-03 00:00:00', -9.810000000000002), ('2023-11-02 00:00:00', -9.810000000000002), ('2023-11-01 00:00:00', -9.810000000000002), ('2023-10-31 00:00:00', 13.870000000000005), ('2023-10-30 00:00:00', 13.870000000000005), ('2023-10-29 00:00:00', 13.870000000000005), ('2023-10-28 00:00:00', 13.870000000000005), ('2023-10-27 00:00:00', 13.870000000000005), ('2023-10-26 00:00:00', 13.870000000000005), ('2023-10-25 00:00:00', 13.870000000000005), ('2023-10-24 00:00:00', 13.870000000000005), ('2023-10-23 00:00:00', 13.870000000000005), ('2023-10-22 00:00:00', 13.870000000000005), ('2023-10-21 00:00:00', 13.870000000000005), ('2023-10-20 00:00:00', 13.870000000000005), ('2023-10-19 00:00:00', 13.870000000000005), ('2023-10-18 00:00:00', 13.870000000000005), ('2023-10-17 00:00:00', 13.870000000000005), ('2023-10-16 00:00:00', 13.870000000000005), ('2023-10-15 00:00:00', 13.870000000000005), ('2023-10-14 00:00:00', 13.870000000000005), ('2023-10-13 00:00:00', 13.870000000000005), ('2023-10-12 00:00:00', 13.870000000000005), ('2023-10-11 00:00:00', 13.870000000000005), ('2023-10-10 00:00:00', 13.870000000000005), ('2023-10-09 00:00:00', 13.870000000000005), ('2023-10-08 00:00:00', 13.870000000000005), ('2023-10-07 00:00:00', 13.870000000000005), ('2023-10-06 00:00:00', 13.870000000000005), ('2023-10-05 00:00:00', 13.870000000000005), ('2023-10-04 00:00:00', 13.870000000000005), ('2023-10-03 00:00:00', 1.5999999999999943), ('2023-10-02 00:00:00', -3.299999999999983), ('2023-10-01 00:00:00', 0.14999999999997726), ('2023-09-30 00:00:00', 2.5900000000000034), ('2023-09-29 00:00:00', 2.5900000000000034), ('2023-09-28 00:00:00', 2.5900000000000034), ('2023-09-27 00:00:00', 2.5900000000000034), ('2023-09-26 00:00:00', 2.5900000000000034), ('2023-09-25 00:00:00', 2.5900000000000034), ('2023-09-24 00:00:00', 2.5900000000000034), ('2023-09-23 00:00:00', 2.5900000000000034), ('2023-09-22 00:00:00', 2.5900000000000034), ('2023-09-21 00:00:00', 2.5900000000000034), ('2023-09-20 00:00:00', 2.5900000000000034), ('2023-09-19 00:00:00', 2.5900000000000034), ('2023-09-18 00:00:00', 2.5900000000000034), ('2023-09-17 00:00:00', 2.5900000000000034), ('2023-09-16 00:00:00', 2.5900000000000034), ('2023-09-15 00:00:00', 2.5900000000000034), ('2023-09-14 00:00:00', 2.5900000000000034), ('2023-09-13 00:00:00', 2.5900000000000034), ('2023-09-12 00:00:00', 2.5900000000000034), ('2023-09-11 00:00:00', 2.5900000000000034), ('2023-09-10 00:00:00', 2.5900000000000034), ('2023-09-09 00:00:00', 2.5900000000000034), ('2023-09-08 00:00:00', 2.5900000000000034), ('2023-09-07 00:00:00', 2.5900000000000034), ('2023-09-06 00:00:00', 2.5900000000000034), ('2023-09-05 00:00:00', 2.5900000000000034), ('2023-09-04 00:00:00', 2.5900000000000034), ('2023-09-03 00:00:00', 2.590000000000 ...

# %%
before_start['Change'] = 0
for i in range(before_start.shape[0]):
    date = before_start["Date"].iloc[i]
    if str(date) in changes:
        change = changes[str(date)]
        before_start["Change"].iloc[i] = change
before_start.head(10)
# Out:
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\916556137.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   before_start['Change'] = 0
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_58308\916556137.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   before_start["Change"].iloc[i] = change
#     Unnamed: 0       Date                                               Text  \
# 3            3 2023-04-09  полиц ира будет отслежива ношен хиджаб помощ к...
# 8            8 2023-04-09  три ракет был выпущ сир сторон голанск высот а...
# 10          10 2023-04-08  произошл ден суббот апрел ракет крым учен тайв...
# 13          13 2023-04-08  сотрудник tesla год пересыла друг друг виде ка...
# 14          14 2023-04-08  twitch wikimedia гроз миллион штраф неудален з...
# 15          15 2023-04-08  большинств россия увидел дефицит нужн иностра ...
# 19          19 2023-04-08  лавр возглав делегац росс конференц стран сосе...
# 22          22 2023-04-07  произошл ден пятниц апрел нов рекорд курс валю...
# 23          23 2023-04-07  минторг сша рассматрива введен мер отношен про...
# 24          24 2023-04-07  рубл заверш торг пятниц небольш повышен доллар...
#
#     Change
# 3     11.2
# 8     11.2
# 10    11.2
# 13    11.2
# 14    11.2
# 15    11.2
# 19    11.2
# 22    11.2
# 23    11.2
# 24    11.2
