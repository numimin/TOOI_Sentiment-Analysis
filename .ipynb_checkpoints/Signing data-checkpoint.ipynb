# %%
import pandas as pd
df = pd.read_csv("./all.csv", parse_dates=True)
df
# Out:
#         Unnamed: 0.1  Unnamed: 0        Date
# 0                168         168  2023-04-12  \
# 1                128         128  2023-04-12
# 2                174         174  2023-04-12
# 3                172         172  2023-04-12
# 4                170         170  2023-04-12
# ...              ...         ...         ...
# 144344         81842       81842  2015-01-01
# 144345         81843       81843  2015-01-01
# 144346         81846       81846  2015-01-01
# 144347         81845       81845  2015-01-01
# 144348         81844       81844  2015-01-01
#
#                                                      Text      Site
# 0       «ментовские войны» обошли приквел «игры престо...       rbc  \
# 1       рпц назвала «странной» возможность пасхального...       rbc
# 2       «великий отказ»  компании россии теряют деньги...       rbc
# 3       набиуллина увидела поводов влияния курс рубля ...       rbc
# 4       британия ввела санкции против usm усманова чле...       rbc
# ...                                                   ...       ...
# 144344  cудмедэксперты приступили осмотру тел жертв кр...  interfax
# 144345  кадыров сообщил уничтожении главаря бандгруппы...  interfax
# 144346  роспотребнадзор призвал россиян переедать напи...  interfax
# 144347  российские спасатели присоединились поискам ма...  interfax
# 144348   ряде регионов центральной россии отменили эле...  interfax
#
#                                                       URL
# 0       https://www.rbc.ru/technology_and_media/12/04/...
# 1       https://www.rbc.ru/politics/12/04/2023/64368d1...
# 2       https://pro.rbc.ru/news/642fddfc9a794725b5dc71...
# 3       https://www.rbc.ru/economics/12/04/2023/64365f...
# 4       https://www.rbc.ru/politics/12/04/2023/6436633...
# ...                                                   ...
# 144344                                                NaN
# 144345                                                NaN
# 144346                                                NaN
# 144347                                                NaN
# 144348                                                NaN
#
# [144349 rows x 6 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'])
words = [
    "газпром",
    "газпрома",
    "газпромом",
    "газпрому",
    "газ",
    "газа",
    "газов",
    "газом",
    "газами",
    "газы",
    "газам",
    "газу",
    "газе",
    "газах",
    "нефть",
    "нефти",
    "нефтей",
    "нефтям",
    "нефтями",
    "нефтях",
    "нефтью",
    "бензин",
    "бензины",
    "бензина",
    "бензинов",
    "бензину",
    "бензинам",
    "бензином",
    "бензинами",
    "бензине",
    "бензинах",
    "санкции",
    "санкция",
    "санкций",
    "санкциям",
    "санкцию",
    "санкцией",
    "санкциями",
    "санкциях",
    "кризис",
    "кризисы",
    "кризиса",
    "кризисов",
    "кризису",
    "кризисам",
    "кризисом",
    "кризисами",
    "кризисе",
    "кризисах",
    "рубль",
    "рубли",
    "рубля",
    "рублей",
    "рублю",
    "рублям",
    "рублем",
    "рублями",
    "рубле",
    "рублях"
    "рост",
    "роста",
    "ростов",
    "росту",
    "ростам",
    "ростом",
    "ростами",
    "ростах",
    "росте",
    "падение",
    "падения",
    "падений",
    "падению",
    "падениям",
    "падением",
    "падениями",
    "падении",
    "падениях",
    "цена",
    "цены",
    "цен",
    "цене",
    "ценам",
    "цену",
    "ценой",
    "ценами",
    "ценах",
    "подорожание",
    "удешевение"
]

import time

_filter = df['Text'].str.contains(" " + words[0] + " ")
for w in words:
    _filter |= df['Text'].str.contains(" " + w + " ")
    _filter |= df['Text'].str.contains("^" + w + " ")
    _filter |= df['Text'].str.contains(" " + w + "$")
df['HasWords'] = _filter
df
# Out:
# 87
# 2.7641847133636475
# 2.7209112644195557
# 2.8107974529266357
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 100
#      98 start = time.time()
#      99 _filter |= df['Text'].str.contains(" " + w + " ")
# --> 100 _filter |= df['Text'].str.contains("^" + w + " ")
#     101 _filter |= df['Text'].str.contains(" " + w + "$")
#     102 end = time.time()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\strings\accessor.py:129, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     124     msg = (
#     125         f"Cannot use .str.{func_name} with values of "
#     126         f"inferred dtype '{self._inferred_dtype}'."
#     127     )
#     128     raise TypeError(msg)
# --> 129 return func(self, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\strings\accessor.py:1263, in StringMethods.contains(self, pat, case, flags, na, regex)
#    1255 if regex and re.compile(pat).groups:
#    1256     warnings.warn(
#    1257         "This pattern is interpreted as a regular expression, and has "
#    1258         "match groups. To actually get the groups, use str.extract.",
#    1259         UserWarning,
#    1260         stacklevel=find_stack_level(),
#    1261     )
# -> 1263 result = self._data.array._str_contains(pat, case, flags, na, regex)
#    1264 return self._wrap_result(result, fill_value=na, returns_string=False)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\strings\object_array.py:143, in ObjectStringArrayMixin._str_contains(self, pat, case, flags, na, regex)
#     141         upper_pat = pat.upper()
#     142         f = lambda x: upper_pat in x.upper()
# --> 143 return self._str_map(f, na, dtype=np.dtype("bool"))
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\strings\object_array.py:76, in ObjectStringArrayMixin._str_map(self, f, na_value, dtype, convert)
#      74 map_convert = convert and not np.all(mask)
#      75 try:
# ---> 76     result = lib.map_infer_mask(arr, f, mask.view(np.uint8), map_convert)
#      77 except (TypeError, AttributeError) as err:
#      78     # Reraise the exception if callable `f` got wrong number of args.
#      79     # The user may want to be warned by this, instead of getting NaN
#      80     p_err = (
#      81         r"((takes)|(missing)) (?(2)from \d+ to )?\d+ "
#      82         r"(?(3)required )positional arguments?"
#      83     )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\_libs\lib.pyx:2786, in pandas._libs.lib.map_infer_mask()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\strings\object_array.py:136, in ObjectStringArrayMixin._str_contains.<locals>.<lambda>(x)
#     132         flags |= re.IGNORECASE
#     134     pat = re.compile(pat, flags=flags)
# --> 136     f = lambda x: pat.search(x) is not None
#     137 else:
#     138     if case:
#
# KeyboardInterrupt:

# %%
funds = pd.read_excel("./gazprom-moscow-exchange.xlsx")
funds['Дата'] = pd.to_datetime(funds['Дата'], dayfirst=True)
funds['Change'] = 0
funds = funds.sort_values("Дата")
for i in range(1, funds.shape[0]):
    funds['Change'].iloc[i] = funds['Цена avg'].iloc[i] - funds['Цена avg'].iloc[i - 1]
funds.tail(10)

# %%
import datetime

changes = {}
for i in range(1, funds.shape[0]):
    start = funds["Дата"].iloc[i - 1]
    end = funds["Дата"].iloc[i]
    date = start
    while date < end:
        changes[str(date)] = funds['Change'].iloc[i]
        date += datetime.timedelta(days=1)
        
df['Change'] = 0
for i in range(df.shape[0]):
    date = df["Date"].iloc[i]
    if str(date) in changes:
        change = changes[str(date)]
        df["Change"].iloc[i] = change
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 import datetime
#       3 changes = {}
# ----> 4 for i in range(1, funds.shape[0]):
#       5     start = funds["Дата"].iloc[i - 1]
#       6     end = funds["Дата"].iloc[i]
#
# NameError: name 'funds' is not defined

# %%
df['ChangeSign'] = 0
for i in range(df.shape[0]):
    if df['HasWords'].iloc[i]:
        df['ChangeSign'].iloc[i] = 1 if df['Change'].iloc[i] > 0 else 0 if df['Change'].iloc[i] == 0 else -1
df
# Out:
# C:\Users\Egor Kolyuzhnov\AppData\Local\Temp\ipykernel_177908\1282733176.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ChangeSign'].iloc[i] = 1 if df['Change'].iloc[i] > 0 else 0 if df['Change'].iloc[i] == 0 else -1
#              Date                                               Text  \
# 0      2023-04-12  «ментовск войны» обошл приквел «игр престолов»...
# 1      2023-04-12  рпц назва «странной» возможн пасхальн перемир ...
# 2      2023-04-12  «велик отказ» компан росс теря деньг массов фе...
# 3      2023-04-12  набиуллин увидел повод влиян курс рубл цб выст...
# 4      2023-04-12  британ ввел санкц прот usm усманов член сем ке...
# ...           ...                                                ...
# 144344 2015-01-01  cудмедэксперт приступ осмотр тел жертв крушен ...
# 144345 2015-01-01  кадыр сообщ уничтожен главар бандгрупп мус зав...
# 144346 2015-01-01  роспотребнадзор призва россия перееда напива п...
# 144347 2015-01-01  российск спасател присоедин поиск малайзийск с...
# 144348 2015-01-01  ряд регион центральн росс отмен электричк объе...
#
#         HasWords  Change  ChangeSign
# 0           True     0.0           0
# 1          False     0.0           0
# 2          False     0.0           0
# 3           True     0.0           0
# 4           True     0.0           0
# ...          ...     ...         ...
# 144344     False     0.0           0
# 144345     False     0.0           0
# 144346     False     0.0           0
# 144347     False     0.0           0
# 144348     False     0.0           0
#
# [144349 rows x 5 columns]

# %%
df = df.drop(columns=["Unnamed: 0"])
df
# Out:
#              Date                                               Text  \
# 0      2023-04-12  «ментовск войны» обошл приквел «игр престолов»...
# 1      2023-04-12  рпц назва «странной» возможн пасхальн перемир ...
# 2      2023-04-12  «велик отказ» компан росс теря деньг массов фе...
# 3      2023-04-12  набиуллин увидел повод влиян курс рубл цб выст...
# 4      2023-04-12  британ ввел санкц прот usm усманов член сем ке...
# ...           ...                                                ...
# 144344 2015-01-01  cудмедэксперт приступ осмотр тел жертв крушен ...
# 144345 2015-01-01  кадыр сообщ уничтожен главар бандгрупп мус зав...
# 144346 2015-01-01  роспотребнадзор призва россия перееда напива п...
# 144347 2015-01-01  российск спасател присоедин поиск малайзийск с...
# 144348 2015-01-01  ряд регион центральн росс отмен электричк объе...
#
#         HasWords  Change  ChangeSign
# 0           True     0.0          -1
# 1          False     0.0           0
# 2          False     0.0           0
# 3           True     0.0          -1
# 4           True     0.0          -1
# ...          ...     ...         ...
# 144344     False     0.0           0
# 144345     False     0.0           0
# 144346     False     0.0           0
# 144347     False     0.0           0
# 144348     False     0.0           0
#
# [144349 rows x 5 columns]

# %%
df.to_csv('./signed.csv', encoding='utf-8-sig')

# %%
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_177908\382166389.py in <module>
#       1 with open("./words.txt") as file:
# ----> 2     lines = [line.rstrip() for line in file]
#       3 print(lines)
#
# ~\AppData\Local\Temp\ipykernel_177908\382166389.py in <listcomp>(.0)
#       1 with open("./words.txt") as file:
# ----> 2     lines = [line.rstrip() for line in file]
#       3 print(lines)
#
# ~\anaconda3\lib\encodings\cp1251.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#      25 class StreamWriter(Codec,codecs.StreamWriter):
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x98 in position 451: character maps to <undefined>
